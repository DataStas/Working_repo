# %%
ins = ['abc', 'BaC', 'CaB', 'AbC', 'ab', 'bA']

# %%
l = [''.join(sorted(n.lower())) for n in ins]
d = {}
print(l)
for ind, name in enumerate(l):
    if name not in d:
        d[name] = 1
    else:
        d[name] += 1
# Out:
# ['abc', 'abc', 'abc', 'abc', 'ab', 'ab']

# %%
d
# Out:
# {'abc': 4, 'ab': 2}
