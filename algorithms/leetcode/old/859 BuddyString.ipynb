# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def buddyStrings(self, s: str, goal: str) -> bool:
        letters_not_on_position = 0
        if len(s) != len(goal):
            return False
        elif s == goal:
            return True
        else:
            for ind, letter in enumerate(goal):
                print(ind, letter)
                if (s[ind] != letter) or and letters_not_on_position < 2:
                    if letters_not_on_position == 0:
                        save_ind_1 = ind
                        letters_not_on_position += 1
                    elif letters_not_on_position == 1:
                        save_ind_2 = ind
                        letters_not_on_position += 1
                        break
                else:
                    return False
        return True if s[save_ind_1] == goal[save_ind_2] and s[save_ind_2] == goal[save_ind_1] else False

# %%
class Solution:
    def buddyStrings(self, s: str, goal: str) -> bool:
        index_storage = []
        unique_letters = set(s)
        if len(s) != len(goal):
            for ind, letter in enumerate(s):
                if letter != goal[ind]:
                    index_storage.append(ind)
        if len(index_storage != 2):
            return False
        else:
            s[:index_storage]

# %%
class Solution:
    def buddyStrings(self, s: str, goal: str) -> bool:
        dic_letter = {}
        dic_letter = dic_letter.fromkeys(set(s), [])
        print(dic_letter[s[0]] += 1)
        for ind, letter in enumerate(s):
            dic_letter[letter].append(ind)
        print(dic_letter)
                
        return False
# Out:
#   Input In [29]
#     print(dic_letter[s[0]] += 1)
#                            ^
# SyntaxError: invalid syntax

# %%
class Solution:
    def buddyStrings(self, s: str, goal: str) -> bool:
        if len(s) != len(goal): return False
        if s == goal:
            return True if len(s) - len(set(goal)) >= 1 else False
        diff = []
        for i in range(len(s)):
            if s[i] != goal[i]:
                diff.append(i)
                if len(diff) > 2: return False
        if len(diff) != 2: return False
        if s[diff[0]] == goal[diff[1]] and s[diff[1]] == goal[diff[0]]:
            return True
        
        return False

# %%
S = Solution()

# %%
S.buddyStrings("abcd","badc")
# Out:
# False

# %%
seth = {}

# %%
seth['a'] = 1

# %%
seth['a'] += 1

# %%
seth.values()
# Out:
# dict_values([2])

# %%
string_example = "qwrasfa"

# %%
sk = set(string_example)

# %%
dic_letter = dic_letter.fromkeys(set(sk), [])
for ind, letter in enumerate(string_example):
    print(letter)
    dic_letter[letter].append(ind)
# Out:
# q
# w
# r
# a
# s
# f
# a

# %%
dic_letter
# Out:
# {}
