# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def isLongPressedName(self, name, typed) -> bool:
        ans = ''
        for letter in typed:
            if letter not in ans:
                ans += letter
        return True if ans == name else False

# %%
S = Solution()

# %%
S.isLongPressedName("saeed", "ssaaedd")
# Out:
# saed
# False
