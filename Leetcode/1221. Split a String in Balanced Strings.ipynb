# %%
from collections import Counter

# %%
s = "RLRRLLRLRL"
def make_dup(sub_s: str)-> str:
    rev_s = ""
    for c in sub_s:
        if c == 'R':
            rev_s += 'L'
        else:
            rev_s += 'R'
    return rev_s


window = [n for n in range(2, len(s), 2)]
ans = 0
for w in window:

# %%
ans
# Out:
# 4

# %%
s = "RLRRLLRLRL"
ans = l = 0
for c in s:
    if c == 'L':
        l += 1
    else:
        l -= 1
    if l == 0:
        ans += 1
# Out:
# [2, 4, 6, 8]

# %%
s[0:2]
# Out:
# 'RLRR'
